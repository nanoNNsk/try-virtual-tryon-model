# %% [markdown]
# # 👕 OOTDiffusion Virtual Try-On (ComfyUI Colab)
# **OOTDiffusion** provides natural garment warping and high-quality results.
#
# ---
# Developed by **nano**

# %%
#@title 1. Install
# %cd /content
# !git clone https://github.com/comfyanonymous/ComfyUI
# %cd /content/ComfyUI
# !pip install xformers -r requirements.txt

# %cd /content/ComfyUI/custom_nodes
# !git clone https://github.com/ltdrdata/ComfyUI-Manager.git
# !git clone https://github.com/ZHO-ZHO-ZHO/ComfyUI-OOTDiffusion.git

# %cd /content/ComfyUI/custom_nodes/ComfyUI-OOTDiffusion
# !pip install -r requirements.txt

# %%
#@title 2. Download OOTDiffusion Weights
# %cd /content/ComfyUI/custom_nodes/ComfyUI-OOTDiffusion/checkpoints
# !apt-get -y install -qq aria2
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/levihsu/OOTDiffusion/resolve/main/checkpoints/human_parsing.bin
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/levihsu/OOTDiffusion/resolve/main/checkpoints/openpose.bin

# %%
#@title 3. Launch
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb

import subprocess, threading, time, socket
def iframe_thread(port):
  while True:
      time.sleep(0.5)
      if socket.socket(socket.AF_INET, socket.SOCK_STREAM).connect_ex(('127.0.0.1', port)) == 0: break
  p = subprocess.Popen(["cloudflared", "tunnel", "--url", "http://127.0.0.1:{}".format(port)], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
  for line in p.stderr:
    if "trycloudflare.com " in line.decode(): print("URL:", line.decode()[line.decode().find("http"):])

threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()
# %cd /content/ComfyUI
# !python main.py --dont-print-server
